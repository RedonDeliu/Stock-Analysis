# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pandas import DataFrame, Series

# For time stamps
from datetime import datetime

# For division
from __future__ import division

# %%
sns.set_style('whitegrid')

# %%
import yfinance as yf

# %%
stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
end = datetime.now()
start = datetime(end.year-1, end.month, end.day)

# %%
for stock in stocks:
    globals()[stock] = yf.download(stock, start, end)
#AAPL = yf.download("AAPL", start, end)
#GOOG = DataReader(stock[1], 'yahoo', start, end)
#MSFT = DataReader(stock[2], 'yahoo', start, end)
#AMZN = DataReader(stock[3], 'yahoo', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2023-12-22 00:00:00+00:00  192.656189  193.600006  195.410004  192.970001
# 2023-12-26 00:00:00+00:00  192.108871  193.050003  193.889999  192.830002
# 2023-12-27 00:00:00+00:00  192.208359  193.149994  193.500000  191.089996
# 2023-12-28 00:00:00+00:00  192.636261  193.580002  194.660004  193.169998
# 2023-12-29 00:00:00+00:00  191.591385  192.529999  194.399994  191.729996
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  251.039993  251.039993  251.380005  247.649994
# 2024-12-17 00:00:00+00:00  253.479996  253.479996  253.830002  249.779999
# 2024-12-18 00:00:00+00:00  248.050003  248.050003  254.279999  247.740005
# 2024-12-19 00:00:00+00:00  249.789993  249.789993  252.000000  247.089996
# 2024-12-20 00:00:00+00:00  254.490005  254.490005  255.000000  245.690002
#
# ...

# %%
GOOG
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           GOOG        GOOG        GOOG        GOOG
# Date
# 2023-12-22 00:00:00+00:00  142.209030  142.720001  143.250000  142.054993
# 2023-12-26 00:00:00+00:00  142.308670  142.820007  143.945007  142.500000
# 2023-12-27 00:00:00+00:00  140.933624  141.440002  143.320007  141.050995
# 2023-12-28 00:00:00+00:00  140.774185  141.279999  142.270004  140.828003
# 2023-12-29 00:00:00+00:00  140.425430  140.929993  141.434998  139.899994
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  198.160004  198.160004  200.639999  194.110001
# 2024-12-17 00:00:00+00:00  197.119995  197.119995  202.880005  196.690002
# 2024-12-18 00:00:00+00:00  190.149994  190.149994  198.690002  189.279999
# 2024-12-19 00:00:00+00:00  189.699997  189.699997  194.600006  189.520004
# 2024-12-20 00:00:00+00:00  192.960007  192.960007  194.134995  186.369995
#
# ...

# %%
MSFT
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 2023-12-22 00:00:00+00:00  371.799744  374.579987  375.179993  372.709991
# 2023-12-26 00:00:00+00:00  371.879120  374.660004  376.940002  373.500000
# 2023-12-27 00:00:00+00:00  371.293518  374.070007  375.059998  372.809998
# 2023-12-28 00:00:00+00:00  372.494537  375.279999  376.459991  374.160004
# 2023-12-29 00:00:00+00:00  373.248871  376.040009  377.160004  373.480011
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  451.589996  451.589996  452.179993  445.279999
# 2024-12-17 00:00:00+00:00  454.459991  454.459991  455.290009  449.570007
# 2024-12-18 00:00:00+00:00  437.390015  437.390015  452.649994  437.019989
# 2024-12-19 00:00:00+00:00  437.029999  437.029999  443.179993  436.320007
# 2024-12-20 00:00:00+00:00  436.600006  436.600006  443.739990  428.630005
#
# ...

# %%
AMZN
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AMZN        AMZN        AMZN        AMZN
# Date
# 2023-12-22 00:00:00+00:00  153.419998  153.419998  154.350006  152.710007
# 2023-12-26 00:00:00+00:00  153.410004  153.410004  153.979996  153.029999
# 2023-12-27 00:00:00+00:00  153.339996  153.339996  154.779999  153.119995
# 2023-12-28 00:00:00+00:00  153.380005  153.380005  154.080002  152.949997
# 2023-12-29 00:00:00+00:00  151.940002  151.940002  153.889999  151.029999
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  232.929993  232.929993  233.000000  228.009995
# 2024-12-17 00:00:00+00:00  231.149994  231.149994  232.729996  227.850006
# 2024-12-18 00:00:00+00:00  220.520004  220.520004  231.399994  220.110001
# 2024-12-19 00:00:00+00:00  223.289993  223.289993  226.089996  222.919998
# 2024-12-20 00:00:00+00:00  224.919998  224.919998  226.210007  218.729996
#
# ...

# %%
# Bej describe cdo kompanie
AAPL.describe()
# Out:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        AAPL        AAPL        AAPL        AAPL        AAPL
# count   251.000000  251.000000  251.000000  251.000000  251.000000
# mean    205.324938  205.781275  207.481355  203.811634  205.539283
# std      24.692844   24.486532   24.586593   24.081547   24.287078
# min     164.405121  165.000000  166.399994  164.080002  165.350006
# 25%     183.418915  184.199997  185.119995  182.180000  183.735001
# 50%     212.011078  212.490005  214.860001  208.850006  212.089996
# 75%     226.540764  226.790001  228.580002  224.600006  226.869995
# max     254.490005  254.490005  255.000000  249.779999  252.160004
#
# Price         Volume
# Ticker          AAPL
# count   2.510000e+02
# mean    5.728106e+07
# std     3.080403e+07
# min     2.811130e+07
# 25%     4.198310e+07
# 50%     4.994790e+07
# 75%     6.295815e+07
# max     3.186799e+08

# %%
GOOG.describe()
# Out:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        GOOG        GOOG        GOOG        GOOG        GOOG
# count   251.000000  251.000000  251.000000  251.000000  251.000000
# mean    163.700501  164.106932  165.739753  162.506601  164.035785
# std      15.206971   15.144532   15.391065   14.959923   15.133028
# min     132.085388  132.559998  134.020004  131.550003  132.740005
# 25%     151.396011  151.940002  153.064995  150.580002  151.709999
# 50%     165.085159  165.490005  167.399994  164.500000  165.820007
# 75%     175.060989  175.689995  177.399498  174.029999  175.502502
# max     198.160004  198.160004  202.880005  196.690002  198.529999
#
# Price         Volume
# Ticker          GOOG
# count   2.510000e+02
# mean    1.978988e+07
# std     8.260232e+06
# min     7.409100e+06
# 25%     1.456815e+07
# 50%     1.754820e+07
# 75%     2.162350e+07
# max     5.972800e+07

# %%
MSFT.describe()
# Out:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        MSFT        MSFT        MSFT        MSFT        MSFT
# count   251.000000  251.000000  251.000000  251.000000  251.000000
# mean    417.510012  419.138565  422.424701  415.538525  419.176653
# std      19.185836   18.762647   18.787441   18.564434   18.697983
# min     365.020386  367.750000  372.059998  366.500000  368.970001
# 25%     406.897369  408.744995  412.684998  405.445007  408.640015
# 50%     416.812897  417.880005  421.779999  414.750000  418.250000
# 75%     427.353622  428.970001  431.839996  425.440002  428.625000
# max     465.786438  467.559998  468.350006  464.459991  467.000000
#
# Price         Volume
# Ticker          MSFT
# count   2.510000e+02
# mean    2.066450e+07
# std     7.320168e+06
# min     9.932800e+06
# 25%     1.627200e+07
# 50%     1.909290e+07
# 75%     2.259525e+07
# max     6.423520e+07

# %%
AMZN.describe()
# Out:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        AMZN        AMZN        AMZN        AMZN        AMZN
# count   251.000000  251.000000  251.000000  251.000000  251.000000
# mean    183.053068  183.053068  184.885578  181.023984  183.022829
# std      16.863194   16.863194   17.063619   16.622246   16.841984
# min     144.570007  144.570007  146.589996  144.050003  144.690002
# 25%     174.605003  174.605003  176.575005  173.279999  174.665001
# 50%     182.809998  182.809998  184.929993  180.880005  182.910004
# 75%     188.905006  188.905006  190.670006  186.954994  189.224998
# max     232.929993  232.929993  233.000000  228.009995  232.389999
#
# Price         Volume
# Ticker          AMZN
# count   2.510000e+02
# mean    4.119755e+07
# std     1.611253e+07
# min     2.164740e+07
# 25%     3.116980e+07
# 50%     3.770760e+07
# 75%     4.467150e+07
# max     1.414484e+08

# %%
# Merr info per data
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2023-12-22 00:00:00+00:00 to 2024-12-20 00:00:00+00:00
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  251 non-null    float64
#  1   (Close, AAPL)      251 non-null    float64
#  2   (High, AAPL)       251 non-null    float64
#  3   (Low, AAPL)        251 non-null    float64
#  4   (Open, AAPL)       251 non-null    float64
#  5   (Volume, AAPL)     251 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB

# %%
# Merr info ne lidhje me cmimin dhe kohes
AAPL['Adj Close'].plot(legend=True, figsize=(10, 4));

# %%
AAPL['Volume'].plot(legend=True, figsize=(10, 4));

# %%
# Info per moving average
url1 = 'http://www.investopedia.com/terms/m/movingaverage.asp'
url2 = 'http://www.investopedia.com/articles/active-trading/052014/how-use-moving-average-buy-stocks.asp'
import webbrowser
webbrowser.open(url1)
webbrowser.open(url2)
# Out:
# True

# %%
# Moving Average
ma_day = [10 ,20, 50]

# %%
for ma in ma_day:
    column_name = "MA for "+(str(ma))+" days" 
    AAPL[column_name] = AAPL['Adj Close'].rolling(ma).mean()
    # Merr 2 argumenta, kolonen edhe nr e diteve

# %%
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots=False, figsize=(10, 4))
# Out:
# <Axes: xlabel='Date'>

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2023-12-22 00:00:00+00:00  192.656189  193.600006  195.410004  192.970001
# 2023-12-26 00:00:00+00:00  192.108871  193.050003  193.889999  192.830002
# 2023-12-27 00:00:00+00:00  192.208359  193.149994  193.500000  191.089996
# 2023-12-28 00:00:00+00:00  192.636261  193.580002  194.660004  193.169998
# 2023-12-29 00:00:00+00:00  191.591385  192.529999  194.399994  191.729996
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  251.039993  251.039993  251.380005  247.649994
# 2024-12-17 00:00:00+00:00  253.479996  253.479996  253.830002  249.779999
# 2024-12-18 00:00:00+00:00  248.050003  248.050003  254.279999  247.740005
# 2024-12-19 00:00:00+00:00  249.789993  249.789993  252.000000  247.089996
# 2024-12-20 00:00:00+00:00  254.490005  254.490005  255.000000  245.690002
#
# ...

# %%
AAPL['Adj Close'].rolling(10).mean().plot(figsize=(11, 4));

# %%
# Daily Return
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()
# pct change eshte percentage change

# %%
AAPL['Daily Return']
# Out:
# Date
# 2023-12-22 00:00:00+00:00         NaN
# 2023-12-26 00:00:00+00:00   -0.002841
# 2023-12-27 00:00:00+00:00    0.000518
# 2023-12-28 00:00:00+00:00    0.002226
# 2023-12-29 00:00:00+00:00   -0.005424
#                                ...
# 2024-12-16 00:00:00+00:00    0.011728
# 2024-12-17 00:00:00+00:00    0.009720
# 2024-12-18 00:00:00+00:00   -0.021422
# 2024-12-19 00:00:00+00:00    0.007015
# 2024-12-20 00:00:00+00:00    0.018816
# Name: Daily Return, Length: 251, dtype: float64

# %%
AAPL['Daily Return'].describe()
# Out:
# count    250.000000
# mean       0.001215
# std        0.014269
# min       -0.048167
# 25%       -0.006654
# 50%        0.001539
# 75%        0.009102
# max        0.072649
# Name: Daily Return, dtype: float64

# %%
AAPL['Daily Return'].plot(legend=True, figsize=(11, 4), linestyle='--', marker='o');

# %%
sns.boxplot(x='Daily Return', data=AAPL);

# %%
sns.displot(AAPL['Daily Return'].dropna(), bins=100, color='purple');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(AAPL['Daily Return'].dropna(), bins=100, color='purple', kde=True);
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
AAPL['Daily Return'].hist(bins=100);

# %%
closing_df = yf.download(stocks, start, end)['Adj Close']
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
closing_df
# Out:
# Ticker                           AAPL        AMZN        GOOG        MSFT
# Date
# 2023-12-22 00:00:00+00:00  192.656189  153.419998  142.209030  371.799683
# 2023-12-26 00:00:00+00:00  192.108841  153.410004  142.308670  371.879150
# 2023-12-27 00:00:00+00:00  192.208359  153.339996  140.933624  371.293518
# 2023-12-28 00:00:00+00:00  192.636261  153.380005  140.774185  372.494507
# 2023-12-29 00:00:00+00:00  191.591385  151.940002  140.425430  373.248932
# ...                               ...         ...         ...         ...
# 2024-12-16 00:00:00+00:00  251.039993  232.929993  198.160004  451.589996
# 2024-12-17 00:00:00+00:00  253.479996  231.149994  197.119995  454.459991
# 2024-12-18 00:00:00+00:00  248.050003  220.520004  190.149994  437.390015
# 2024-12-19 00:00:00+00:00  249.789993  223.289993  189.699997  437.029999
# 2024-12-20 00:00:00+00:00  254.490005  224.919998  192.960007  436.600006
#
# [251 rows x 4 columns]

# %%
closing_df.describe()
# Out:
# Ticker        AAPL        AMZN        GOOG        MSFT
# count   251.000000  251.000000  251.000000  251.000000
# mean    205.324938  183.053068  163.700501  417.510013
# std      24.692844   16.863194   15.206971   19.185834
# min     164.405121  144.570007  132.085388  365.020416
# 25%     183.418907  174.605003  151.396027  406.897339
# 50%     212.011078  182.809998  165.085159  416.812897
# 75%     226.540764  188.905006  175.060982  427.353638
# max     254.490005  232.929993  198.160004  465.786438

# %%
closing_df.plot(figsize=(11, 4));

# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets
# Out:
# Ticker                         AAPL      AMZN      GOOG      MSFT
# Date
# 2023-12-22 00:00:00+00:00       NaN       NaN       NaN       NaN
# 2023-12-26 00:00:00+00:00 -0.002841 -0.000065  0.000701  0.000214
# 2023-12-27 00:00:00+00:00  0.000518 -0.000456 -0.009662 -0.001575
# 2023-12-28 00:00:00+00:00  0.002226  0.000261 -0.001131  0.003235
# 2023-12-29 00:00:00+00:00 -0.005424 -0.009388 -0.002477  0.002025
# ...                             ...       ...       ...       ...
# 2024-12-16 00:00:00+00:00  0.011728  0.024048  0.035427  0.009659
# 2024-12-17 00:00:00+00:00  0.009720 -0.007642 -0.005248  0.006355
# 2024-12-18 00:00:00+00:00 -0.021422 -0.045987 -0.035359 -0.037561
# 2024-12-19 00:00:00+00:00  0.007015  0.012561 -0.002367 -0.000823
# 2024-12-20 00:00:00+00:00  0.018816  0.007300  0.017185 -0.000984
#
# [251 rows x 4 columns]

# %%
tech_rets.describe()
# Out:
# Ticker        AAPL        AMZN        GOOG        MSFT
# count   250.000000  250.000000  250.000000  250.000000
# mean      0.001215    0.001687    0.001373    0.000721
# std       0.014269    0.017680    0.017458    0.012517
# min      -0.048167   -0.087847   -0.073505   -0.060528
# 25%      -0.006654   -0.008420   -0.008674   -0.005483
# 50%       0.001539    0.000724    0.003410    0.001191
# 75%       0.009102    0.011965    0.010149    0.009153
# max       0.072649    0.078666    0.099652    0.026599

# %%
tech_rets.corr()
# Out:
# Ticker      AAPL      AMZN      GOOG      MSFT
# Ticker
# AAPL    1.000000  0.335500  0.358626  0.467632
# AMZN    0.335500  1.000000  0.532294  0.683786
# GOOG    0.358626  0.532294  1.000000  0.571041
# MSFT    0.467632  0.683786  0.571041  1.000000

# %%
sns.jointplot(x='GOOG', y='GOOG', data=tech_rets, kind='scatter', color='seagreen');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x='GOOG', y='AAPL', data=tech_rets, kind='scatter', color='seagreen');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x='GOOG', y='AMZN', data=tech_rets, kind='scatter', color='seagreen');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x='GOOG', y='MSFT', data=tech_rets, kind='scatter', color='seagreen');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from IPython.display import SVG
SVG(url='http://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg')

# %%
sns.pairplot(tech_rets);
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(closing_df);
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot)
returns_fig.map_diag(plt.hist, bins=30, color='red');
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.heatmap(tech_rets.corr());

# %%
sns.heatmap(tech_rets.corr(), annot=True);

# %%
sns.heatmap(closing_df.corr(), annot=True);

# %%
# Risk Analysis
rets= tech_rets.dropna()

# %%
area = np.pi*20

# %%
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')
plt.xticks(rotation=45)
url = 'https://matplotlib.org/stable/'
webbrowser.open(url)
# Out:
# True

# %%
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')
plt.xticks(rotation=45)
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom', 
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3', color='r'), color='k')

# %%
# Value at risk
sns.displot(AAPL['Daily Return'].dropna(), bins=100, color='purple', kde=True);
# Out:
# C:\Users\redon\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
rets['AAPL'].quantile(0.05)
# 95 percent of times the worst return would be the result
# Out:
# -0.021755342402261412

# %%
# Per info rreth quantile shiko
from IPython.display import YouTubeVideo

YouTubeVideo('https://youtu.be/IFKQLDmRK0Y', width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.youtube.com/embed/https://youtu.be/IFKQLDmRK0Y"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
rets['MSFT'].quantile(0.05)
# Out:
# -0.0219711626847691

# %%
# Geometric Brownian Motion (GBM)
YouTubeVideo('https://youtu.be/y0s2GXREymI', width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.youtube.com/embed/https://youtu.be/y0s2GXREymI"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
url = 'http://www.investopedia.com/articles/07/montecarlo.asp'
webbrowser.open(url)
# Out:
# True

# %%
days = 365

dt = 1/days

mu = rets.mean()['GOOG']

sigma = rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma*np.sqrt(dt))
        drift[x] = mu*dt
        price[x] = price[x-1] + (price[x-1]*(drift[x]+shock[x]))
    
    return price

# %%
GOOG.head()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           GOOG        GOOG        GOOG        GOOG
# Date
# 2023-12-22 00:00:00+00:00  142.209030  142.720001  143.250000  142.054993
# 2023-12-26 00:00:00+00:00  142.308670  142.820007  143.945007  142.500000
# 2023-12-27 00:00:00+00:00  140.933624  141.440002  143.320007  141.050995
# 2023-12-28 00:00:00+00:00  140.774185  141.279999  142.270004  140.828003
# 2023-12-29 00:00:00+00:00  140.425430  140.929993  141.434998  139.899994
#
# Price                            Open    Volume
# Ticker                           GOOG      GOOG
# Date
# 2023-12-22 00:00:00+00:00  142.130005  18494700
# 2023-12-26 00:00:00+00:00  142.979996  11170100
# 2023-12-27 00:00:00+00:00  142.830002  17288400
# 2023-12-28 00:00:00+00:00  141.850006  12192500
# 2023-12-29 00:00:00+00:00  140.679993  14872700

# %%
start_price = 2513.07
for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google!')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for Google!')

# %%
runs = 10000
simulation = np.zeros(runs)
for run in range(runs):
    simulation[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
q = np.percentile(simulation, 1)
plt.hist(simulation, bins=200)

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulation.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Google Stock after %s days" % days, weight='bold');
